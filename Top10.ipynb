# %%
import pandas as pd

df = pd.read_csv("311_Service_Requests_2020.csv")   #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
print (df.head())
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1    45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2    45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3    45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4    45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning  3 or More
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# ...

# %%
#Create a dataset of zipcode: 10025
campusdf = df.loc[df['Incident Zip'] == 10025]
campusdf.head()
# Out:
#       Unique Key            Created Date             Closed Date Agency  \
# 11      45278238  01/01/2020 12:01:46 AM  01/01/2020 05:37:46 AM   NYPD
# 141     45278928  01/01/2020 12:36:42 AM  01/01/2020 01:19:30 AM   NYPD
# 463     45282069  01/01/2020 01:37:02 AM  01/01/2020 01:55:21 AM   NYPD
# 979     45286989  01/01/2020 03:33:15 AM  02/21/2020 08:45:41 AM    TLC
# 1166    45287132  01/01/2020 04:33:27 AM  01/03/2020 05:46:11 AM    HPD
#
#                                             Agency Name  \
# 11                      New York City Police Department
# 141                     New York City Police Department
# 463                     New York City Police Department
# 979                       Taxi and Limousine Commission
# 1166  Department of Housing Preservation and Develop...
#
#                   Complaint Type                    Descriptor  \
# 11           Noise - Residential              Banging/Pounding
# 141          Noise - Residential              Loud Music/Party
# ...

# %%
causes = campusdf.groupby('Complaint Type').size().sort_values(ascending=False)

# %%
top10 = causes.head(10)

# %%
type(top10)
# Out:
# pandas.core.series.Series

# %%
top10
# Out:
# Complaint Type
# Noise - Residential            2952
# Noise - Street/Sidewalk        2128
# HEAT/HOT WATER                 1885
# Noise                          1131
# Illegal Parking                 792
# Noise - Vehicle                 787
# Non-Emergency Police Matter     773
# Rodent                          691
# Illegal Fireworks               672
# UNSANITARY CONDITION            565
# dtype: int64
